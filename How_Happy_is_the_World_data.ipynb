# %% [markdown]
# <a href="https://colab.research.google.com/github/K-Dwivedi/Code-Division--Python-worksheets/blob/main/How_Happy_is_the_World_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # How happy is the world?
#
# ![HappinessImage-Benjamin Scott](https://drive.google.com/uc?id=1wWdXTclLAjPpZUiKkR8XGg0Sl7iD1u8T)
#
# (Image by Benjamin Scott, [source](https://www.natureindex.com/news-blog/data-visualization-these-are-the-happiest-countries-world-happiness-report-twenty-nineteen))
#
# The Sustainable Development Solutions Network (SDSN) collects data across the world relating to happiness.  They use this data to rank countries in order of happiness factor.
#
# This is not an exact science but can give food for thought in terms of what factors might have the most impact on a nation's happiness levels.
#
# Data is taken from the Gallup World Poll, so not collected directly by SDSN.
# Countries are grouped by region.
#
# ### The factors included are:
# Economy (measured in GDP per Capita)
# Family (support systems)
# Health (measured by Life Expectancy)
# Freedom (sense of)
# Trust (Government Corruption)
# Generosity (charitable inclinations)
# Dystopia Residual
# *  Dystopic is the theoretical most unhappy country with the lowest levels in all six of the above factors
# *  The Residual measure is a calculated as the average of the six distances from lowest
#
# Let's take a look at the data

# %% [markdown]
# ---
# ### Open a data set
#
# Open the data set, an Excel file with only one sheet (so sheet_name is not necessary) from here: https://github.com/futureCodersSE/working-with-data/blob/main/Happiness-Data/2015.xlsx?raw=true
#
# Interrogate the data (head, tail, iloc) to get to know what it contains.

# %% [markdown]
# **Interrogating the data**

# %%
import pandas as pd    # importing pandas to read and manipulate the dataset
url=" https://github.com/futureCodersSE/working-with-data/blob/main/Happiness-Data/2015.xlsx?raw=true"

df=pd.read_excel(url)           # df is the dataframe which is the desired data from dataset(contains in excel file) read by pandas library
df                             # to get the dataframe (two-dimensional data structure in the form of rows and columns) to see what it contains


# as the data shown in df, it has  158 rows and 12 columns
# as the dataset is big so we get first 5 and last 5 records of the dataframe if we don't specify the number of rows
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %% [markdown]
#  **To get first 10 records(rows)**

# %%
df.head(10)
# Out:
#        Country                     Region  Happiness Rank  Happiness Score  \
# 0  Switzerland             Western Europe               1            7.587
# 1      Iceland             Western Europe               2            7.561
# 2      Denmark             Western Europe               3            7.527
# 3       Norway             Western Europe               4            7.522
# 4       Canada              North America               5            7.427
# 5      Finland             Western Europe               6            7.406
# 6  Netherlands             Western Europe               7            7.378
# 7       Sweden             Western Europe               8            7.364
# 8  New Zealand  Australia and New Zealand               9            7.286
# 9    Australia  Australia and New Zealand              10            7.284
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# ...

# %% [markdown]
# **To get last 10 records**

# %%
df.tail(10)
# Out:
#           Country                           Region  Happiness Rank  \
# 148          Chad               Sub-Saharan Africa             149
# 149        Guinea               Sub-Saharan Africa             150
# 150   Ivory Coast               Sub-Saharan Africa             151
# 151  Burkina Faso               Sub-Saharan Africa             152
# 152   Afghanistan                    Southern Asia             153
# 153        Rwanda               Sub-Saharan Africa             154
# 154         Benin               Sub-Saharan Africa             155
# 155         Syria  Middle East and Northern Africa             156
# 156       Burundi               Sub-Saharan Africa             157
# 157          Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 148            3.667         0.03830                   0.34193  0.76062
# 149            3.656         0.03590                   0.17417  0.46475
# ...

# %% [markdown]
# **To get middle 50 records**

# %%
total_length=len(df)    # to get the total length of the dataframe
middle=total_length//2       # to get the middle
print(middle)

df.iloc[middle-25:middle+25]      # to get the middle 50 records
# Out:
# 79
#                     Country                           Region  Happiness Rank  \
# 54                 Slovenia       Central and Eastern Europe              55
# 55                Lithuania       Central and Eastern Europe              56
# 56                Nicaragua      Latin America and Caribbean              57
# 57                     Peru      Latin America and Caribbean              58
# 58                  Belarus       Central and Eastern Europe              59
# 59                   Poland       Central and Eastern Europe              60
# 60                 Malaysia                Southeastern Asia              61
# 61                  Croatia       Central and Eastern Europe              62
# 62                    Libya  Middle East and Northern Africa              63
# 63                   Russia       Central and Eastern Europe              64
# 64                  Jamaica      Latin America and Caribbean              65
# ...

# %% [markdown]
# **To get first 50 records from the specific columns**

# %%
df
df_new=df[['Country','Family','Health (Life Expectancy)','Economy (GDP per Capita)','Happiness Rank']]
print(df_new.head(50))
# Out:
#                  Country   Family  Health (Life Expectancy)  \
# 0            Switzerland  1.34951                   0.94143
# 1                Iceland  1.40223                   0.94784
# 2                Denmark  1.36058                   0.87464
# 3                 Norway  1.33095                   0.88521
# 4                 Canada  1.32261                   0.90563
# 5                Finland  1.31826                   0.88911
# 6            Netherlands  1.28017                   0.89284
# 7                 Sweden  1.28907                   0.91087
# 8            New Zealand  1.31967                   0.90837
# 9              Australia  1.30923                   0.93156
# 10                Israel  1.22393                   0.91387
# 11            Costa Rica  1.23788                   0.86027
# 12               Austria  1.29704                   0.89042
# 13                Mexico  0.91451                   0.81444
# 14         United States  1.24711                   0.86179
# ...

# %% [markdown]
# ---
# ### Sort the data in different ways
#
# The data is currently sorted in order of rank.  To sort the data in the table, run the code below, which identifies the column on which to sort in the brackets.
#
# Then, **try sorting on other columns** *Note: you must type the column heading in the quotes and exactly as it appears in the table (including capitalisation)*.  To sort on multiple columns, enter a list of column headings in the brackets (e.g. `.sort_values(['Region','Freedom'])`

# %%
import pandas as pd    # importing pandas to read and manipulate the dataset
url=" https://github.com/futureCodersSE/working-with-data/blob/main/Happiness-Data/2015.xlsx?raw=true"

df=pd.read_excel(url)           # df is the dataframe which is the desired data from dataset(contains in excel file) read by pandas library
df                             # to get the dataframe (two-dimensional data structure in the form of rows and columns) to see what it contains



happiness=df
sorted_table = happiness.sort_values(['Country','Happiness Rank'])
sorted_table                     # output the table below
# Out:
#          Country                           Region  Happiness Rank  \
# 152  Afghanistan                    Southern Asia             153
# 94       Albania       Central and Eastern Europe              95
# 67       Algeria  Middle East and Northern Africa              68
# 136       Angola               Sub-Saharan Africa             137
# 29     Argentina      Latin America and Caribbean              30
# ..           ...                              ...             ...
# 22     Venezuela      Latin America and Caribbean              23
# 74       Vietnam                Southeastern Asia              75
# 135        Yemen  Middle East and Northern Africa             136
# 84        Zambia               Sub-Saharan Africa              85
# 114     Zimbabwe               Sub-Saharan Africa             115
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 152            3.575         0.03084                   0.31982  0.30285
# ...

# %% [markdown]
# ---
# ### Summarising the data
#
# Look at the happiness dataframe.  Create new dataframes from a range of rows, columns, statistical information, etc.
#
# For each dataframe, add a text cell to explain what it is showing

# %% [markdown]
# **To get the summary of dataframe**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %% [markdown]
# **To get the description of the numerical data from dataframe**

# %%
df.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %% [markdown]
# **Creating new dataframe**

# %%
df[['Country','Happiness Rank','Economy (GDP per Capita)','Freedom','Trust (Government Corruption)']].head(15)
# Out:
#           Country  Happiness Rank  Economy (GDP per Capita)  Freedom  \
# 0     Switzerland               1                   1.39651  0.66557
# 1         Iceland               2                   1.30232  0.62877
# 2         Denmark               3                   1.32548  0.64938
# 3          Norway               4                   1.45900  0.66973
# 4          Canada               5                   1.32629  0.63297
# 5         Finland               6                   1.29025  0.64169
# 6     Netherlands               7                   1.32944  0.61576
# 7          Sweden               8                   1.33171  0.65980
# 8     New Zealand               9                   1.25018  0.63938
# 9       Australia              10                   1.33358  0.65124
# 10         Israel              11                   1.22857  0.41319
# 11     Costa Rica              12                   0.95578  0.63376
# 12        Austria              13                   1.33723  0.62433
# ...

# %% [markdown]
# **To get the total number of rows and columns in the dataframe**

# %%
df.shape
# Out:
# (158, 12)

# %% [markdown]
# **To display the highest GDP**

# %%
df_sorted=df.sort_values(['Economy (GDP per Capita)'])
Highest_GDP_Country=df_sorted
print( Highest_GDP_Country )                                    # I didn't get why all the columns are showing here. Its a confusing for me so far.
# Out:
#               Country                           Region  Happiness Rank  \
# 119  Congo (Kinshasa)               Sub-Saharan Africa             120
# 156           Burundi               Sub-Saharan Africa             157
# 130            Malawi               Sub-Saharan Africa             131
# 143             Niger               Sub-Saharan Africa             144
# 115           Liberia               Sub-Saharan Africa             116
# ..                ...                              ...             ...
# 3              Norway                   Western Europe               4
# 23          Singapore                Southeastern Asia              24
# 38             Kuwait  Middle East and Northern Africa              39
# 16         Luxembourg                   Western Europe              17
# 27              Qatar  Middle East and Northern Africa              28
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# ...

# %% [markdown]
# **Display the mean, max and min for Freedom, mean, max, min and skew for Generosity and mean, min, max and std for GDP**

# %%
df.agg(
    {  "Freedom" :["min","max","mean"],
     "Generosity":["mean","max","min","skew"],
       "Economy (GDP per Capita)":["min","max","std"]
    }
)
# Out:
#        Freedom  Generosity  Economy (GDP per Capita)
# min   0.000000    0.000000                  0.000000
# max   0.669730    0.795880                  1.690420
# mean  0.428615    0.237296                       NaN
# skew       NaN    1.001961                       NaN
# std        NaN         NaN                  0.403121

# %% [markdown]
# **To check duplicates**

# %%
df.duplicated()
print(df.duplicated())

df.duplicated().sum()
print(df.duplicated().sum()  )         #No duplicate values
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 153    False
# 154    False
# 155    False
# 156    False
# 157    False
# Length: 158, dtype: bool
# 0

# %% [markdown]
# **To check null values**

# %%
df.isnull()
df.isnull().sum()              # No null values
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %% [markdown]
# **To display the data in a bar graph**

# %%
df.plot(kind='bar')    # I don't understand how to show top 10-20 countries in the bar chart
# Out:
# <Axes: >

# %% [markdown]
# **To display bar chart using matplotlib library**

# %%
import matplotlib.pyplot as plt

# CREATING A BAR GRAPH REPRESENTATION ON FIRST 10 RECORDS OD THE DATAFRAME

first_10_df=df.head(10)

plt.bar(first_10_df['Country'], first_10_df['Happiness Rank'],first_10_df['Economy (GDP per Capita)'])

# So far I don't understand how to get clear visible country names
# Out:
# <BarContainer object of 10 artists>

# %% [markdown]
# ---
# ### Next steps
#
# There are data sets for the years 2015 to 2019 available.  To access and try out other years, change 2015 to the required year in the URL in the first code cell.  Leave the rest exactly as it is.
#
# Other years may have different column headings and so there will be different data to play with.
